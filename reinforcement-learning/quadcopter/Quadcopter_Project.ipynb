# %% [markdown]
# # Project: Train a Quadcopter How to Fly
#
# Design an agent to fly a quadcopter, and then train it using a reinforcement learning algorithm of your choice!
#
# Try to apply the techniques you have learnt, but also feel free to come up with innovative ideas and test them.

# %% [markdown]
# ## Instructions
#
# Take a look at the files in the directory to better understand the structure of the project.
#
# - `task.py`: Define your task (environment) in this file.
# - `agents/`: Folder containing reinforcement learning agents.
#     - `policy_search.py`: A sample agent has been provided here.
#     - `agent.py`: Develop your agent here.
# - `physics_sim.py`: This file contains the simulator for the quadcopter.  **DO NOT MODIFY THIS FILE**.
#
# For this project, you will define your own task in `task.py`.  Although we have provided a example task to get you started, you are encouraged to change it.  Later in this notebook, you will learn more about how to amend this file.
#
# You will also design a reinforcement learning agent in `agent.py` to complete your chosen task.
#
# You are welcome to create any additional files to help you to organize your code.  For instance, you may find it useful to define a `model.py` file defining any needed neural network architectures.
#
# ## Controlling the Quadcopter
#
# We provide a sample agent in the code cell below to show you how to use the sim to control the quadcopter.  This agent is even simpler than the sample agent that you'll examine (in `agents/policy_search.py`) later in this notebook!
#
# The agent controls the quadcopter by setting the revolutions per second on each of its four rotors.  The provided agent in the `Basic_Agent` class below always selects a random action for each of the four rotors.  These four speeds are returned by the `act` method as a list of four floating-point numbers.
#
# For this project, the agent that you will implement in `agents/agent.py` will have a far more intelligent method for selecting actions!

# %%
import random

class Basic_Agent():
    def __init__(self, task):
        self.task = task
    
    def act(self):
        new_thrust = random.gauss(450., 25.)
        return [new_thrust + random.gauss(0., 1.) for x in range(4)]

# %% [markdown]
# Run the code cell below to have the agent select actions to control the quadcopter.
#
# Feel free to change the provided values of `runtime`, `init_pose`, `init_velocities`, and `init_angle_velocities` below to change the starting conditions of the quadcopter.
#
# The `labels` list below annotates statistics that are saved while running the simulation.  All of this information is saved in a text file `data.txt` and stored in the dictionary `results`.

# %%
# %load_ext autoreload
# %autoreload 2

import csv
import numpy as np
from task import Task

# Modify the values below to give the quadcopter a different starting position.
runtime = 5.                                     # time limit of the episode
init_pose = np.array([0., 0., 10., 0., 0., 0.])  # initial pose
init_velocities = np.array([0., 0., 0.])         # initial velocities
init_angle_velocities = np.array([0., 0., 0.])   # initial angle velocities
file_output = 'data.txt'                         # file name for saved results

# Setup
task = Task(init_pose, init_velocities, init_angle_velocities, runtime)
agent = Basic_Agent(task)
done = False
labels = ['time', 'x', 'y', 'z', 'phi', 'theta', 'psi', 'x_velocity',
          'y_velocity', 'z_velocity', 'phi_velocity', 'theta_velocity',
          'psi_velocity', 'rotor_speed1', 'rotor_speed2', 'rotor_speed3', 'rotor_speed4']
results = {x : [] for x in labels}

# Run the simulation, and save the results.
with open(file_output, 'w') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(labels)
    while True:
        rotor_speeds = agent.act()
        _, _, done = task.step(rotor_speeds)
        to_write = [task.sim.time] + list(task.sim.pose) + list(task.sim.v) + list(task.sim.angular_v) + list(rotor_speeds)
        for ii in range(len(labels)):
            results[labels[ii]].append(to_write[ii])
        writer.writerow(to_write)
        if done:
            break

# %% [markdown]
# Run the code cell below to visualize how the position of the quadcopter evolved during the simulation.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(results['time'], results['x'], label='x')
plt.plot(results['time'], results['y'], label='y')
plt.plot(results['time'], results['z'], label='z')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# The next code cell visualizes the velocity of the quadcopter.

# %%
plt.plot(results['time'], results['x_velocity'], label='x_hat')
plt.plot(results['time'], results['y_velocity'], label='y_hat')
plt.plot(results['time'], results['z_velocity'], label='z_hat')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# Next, you can plot the Euler angles (the rotation of the quadcopter over the $x$-, $y$-, and $z$-axes),

# %%
plt.plot(results['time'], results['phi'], label='phi')
plt.plot(results['time'], results['theta'], label='theta')
plt.plot(results['time'], results['psi'], label='psi')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# before plotting the velocities (in radians per second) corresponding to each of the Euler angles.

# %%
plt.plot(results['time'], results['phi_velocity'], label='phi_velocity')
plt.plot(results['time'], results['theta_velocity'], label='theta_velocity')
plt.plot(results['time'], results['psi_velocity'], label='psi_velocity')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# Finally, you can use the code cell below to print the agent's choice of actions.

# %%
plt.plot(results['time'], results['rotor_speed1'], label='Rotor 1 revolutions / second')
plt.plot(results['time'], results['rotor_speed2'], label='Rotor 2 revolutions / second')
plt.plot(results['time'], results['rotor_speed3'], label='Rotor 3 revolutions / second')
plt.plot(results['time'], results['rotor_speed4'], label='Rotor 4 revolutions / second')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# When specifying a task, you will derive the environment state from the simulator.  Run the code cell below to print the values of the following variables at the end of the simulation:
# - `task.sim.pose` (the position of the quadcopter in ($x,y,z$) dimensions and the Euler angles),
# - `task.sim.v` (the velocity of the quadcopter in ($x,y,z$) dimensions), and
# - `task.sim.angular_v` (radians/second for each of the three Euler angles).

# %%
# the pose, velocity, and angular velocity of the quadcopter at the end of the episode
print(task.sim.pose)
print(task.sim.v)
print(task.sim.angular_v)
# Out:
# [22.12566603 25.6952423  14.98438642  1.17325968  5.4879119   0.        ]
# [11.53959108 12.14851577 -7.56801381]
# [ 0.2373739  -0.15938753  0.        ]

# %% [markdown]
# In the sample task in `task.py`, we use the 6-dimensional pose of the quadcopter to construct the state of the environment at each timestep.  However, when amending the task for your purposes, you are welcome to expand the size of the state vector by including the velocity information.  You can use any combination of the pose, velocity, and angular velocity - feel free to tinker here, and construct the state to suit your task.
#
# ## The Task
#
# A sample task has been provided for you in `task.py`.  Open this file in a new window now.
#
# The `__init__()` method is used to initialize several variables that are needed to specify the task.
# - The simulator is initialized as an instance of the `PhysicsSim` class (from `physics_sim.py`).
# - Inspired by the methodology in the original DDPG paper, we make use of action repeats.  For each timestep of the agent, we step the simulation `action_repeats` timesteps.  If you are not familiar with action repeats, please read the **Results** section in [the DDPG paper](https://arxiv.org/abs/1509.02971).
# - We set the number of elements in the state vector.  For the sample task, we only work with the 6-dimensional pose information.  To set the size of the state (`state_size`), we must take action repeats into account.
# - The environment will always have a 4-dimensional action space, with one entry for each rotor (`action_size=4`). You can set the minimum (`action_low`) and maximum (`action_high`) values of each entry here.
# - The sample task in this provided file is for the agent to reach a target position.  We specify that target position as a variable.
#
# The `reset()` method resets the simulator.  The agent should call this method every time the episode ends.  You can see an example of this in the code cell below.
#
# The `step()` method is perhaps the most important.  It accepts the agent's choice of action `rotor_speeds`, which is used to prepare the next state to pass on to the agent.  Then, the reward is computed from `get_reward()`.  The episode is considered done if the time limit has been exceeded, or the quadcopter has travelled outside of the bounds of the simulation.
#
# In the next section, you will learn how to test the performance of an agent on this task.

# %% [markdown]
# ## The Agent
#
# The sample agent given in `agents/policy_search.py` uses a very simplistic linear policy to directly compute the action vector as a dot product of the state vector and a matrix of weights. Then, it randomly perturbs the parameters by adding some Gaussian noise, to produce a different policy. Based on the average reward obtained in each episode (`score`), it keeps track of the best set of parameters found so far, how the score is changing, and accordingly tweaks a scaling factor to widen or tighten the noise.
#
# Run the code cell below to see how the agent performs on the sample task.

# %%
import sys
import pandas as pd
from agents.policy_search import PolicySearch_Agent
from task import Task

num_episodes = 1000
target_pos = np.array([0., 0., 10.])
task = Task(target_pos=target_pos)
agent = PolicySearch_Agent(task) 

for i_episode in range(1, num_episodes+1):
    state = agent.reset_episode() # start a new episode
    while True:
        action = agent.act(state) 
        next_state, reward, done = task.step(action)
        agent.step(reward, done)
        state = next_state
        if done:
            print("\rEpisode = {:4d}, score = {:7.3f} (best = {:7.3f}), noise_scale = {}".format(
                i_episode, agent.score, agent.best_score, agent.noise_scale), end="")  # [debug]
            break
    sys.stdout.flush()
# Out:
# Episode = 1000, score =  -1.054 (best =   0.247), noise_scale = 3.25

# %% [markdown]
# This agent should perform very poorly on this task.  And that's where you come in!

# %% [markdown]
# ## Define the Task, Design the Agent, and Train Your Agent!
#
# Amend `task.py` to specify a task of your choosing.  If you're unsure what kind of task to specify, you may like to teach your quadcopter to takeoff, hover in place, land softly, or reach a target pose.
#
# After specifying your task, use the sample agent in `agents/policy_search.py` as a template to define your own agent in `agents/agent.py`.  You can borrow whatever you need from the sample agent, including ideas on how you might modularize your code (using helper methods like `act()`, `learn()`, `reset_episode()`, etc.).
#
# Note that it is **highly unlikely** that the first agent and task that you specify will learn well.  You will likely have to tweak various hyperparameters and the reward function for your task until you arrive at reasonably good behavior.
#
# As you develop your agent, it's important to keep an eye on how it's performing. Use the code above as inspiration to build in a mechanism to log/save the total rewards obtained in each episode to file.  If the episode rewards are gradually increasing, this is an indication that your agent is learning.

# %%
## TODO: Train your agent here.
import sys
import numpy as np
import pandas as pd
from agent_ddpg.ddpg_agent import AgentDDPG
from agent_ddpg.task_takeoff import TaskTakeoff

num_episodes = 1000
init_pos = np.array([0., 0., 0., 0., 0., 0.])
init_v = np.array([0., 0., 0.])
init_angle_v = np.array([0., 0., 0.])
target_pos = np.array([0., 0., 10.])

task = TaskTakeoff(init_pose=init_pos, init_velocities=init_v, 
        init_angle_velocities=init_angle_v, target_pos=target_pos)
agent = AgentDDPG(task) 

for i_episode in range(1, num_episodes+1):
    state = agent.reset_episode() # start a new episode
    while True:
        action = agent.act(state) 
        next_state, reward, done = task.step(action)
        agent.step(action, reward, next_state, done)
        state = next_state
        if done:
#             print("\rEpisode = {:4d}, R_total = {:7.3f}, R_average = {:7.3f}, (R_best_average = {:7.3f})".format(
#                 i_episode, agent.total_reward, agent.average_reward, agent.best_average_reward))  
#            print("\rEpisode = {:4d}, R_total = {:7.3f}, R_average = {:7.3f}, (R_best_average = {:7.3f})".format(
#                i_episode, agent.total_reward, agent.average_reward, agent.best_average_reward), end="")  # [debug]
#            print("\rEnd position: ", task.sim.pose, "velocity:", task.sim.v, "angular_velocity:", task.sim.angular_v)

            print("\rEpisode = {:4d}, R_average = {:7.3f}, Position: [{:7.3f},{:7.3f},{:7.3f}]".format(
                i_episode, agent.average_reward, task.sim.pose[0], task.sim.pose[1], task.sim.pose[2]))
            break

    sys.stdout.flush()
# Out:
# Episode =    1, R_average = -12.740, Position: [ -6.485,  2.116,  0.000]
# Episode =    2, R_average =  -5.171, Position: [ -1.831,  2.310,  0.000]
# Episode =    3, R_average =  -1.120, Position: [ -0.229,  0.236,  0.000]
# Episode =    4, R_average =  -1.928, Position: [ -0.439,  0.599,  0.000]
# Episode =    5, R_average =  -0.548, Position: [ -0.028, -0.000,  0.000]
# Episode =    6, R_average =  -1.019, Position: [ -0.172, -0.083,  0.000]
# Episode =    7, R_average =  -0.952, Position: [ -0.119,  0.122,  0.000]
# Episode =    8, R_average =  -0.892, Position: [ -0.037, -0.026,  0.000]
# Episode =    9, R_average =  -1.457, Position: [ -0.667,  0.544,  0.000]
# Episode =   10, R_average =  -0.500, Position: [ -0.090,  0.067,  0.000]
# Episode =   11, R_average =  -0.370, Position: [ -0.092,  0.015,  0.000]
# Episode =   12, R_average =  -0.351, Position: [ -0.024,  0.018,  0.000]
# Episode =   13, R_average =  -0.235, Position: [ -0.028,  0.022,  0.000]
# Episode =   14, R_average =  -0.231, Position: [ -0.033,  0.029,  0.000]
# Episode =   15, R_average =  -0.222, Position: [ -0.039,  0.031,  0.000]
# Episode =   16, R_average =  -0.219, Position: [ -0.048,  0.024,  0.000]
# Episode =   17, R_average =  -0.211, Position: [ -0.059,  0.014,  0.000]
# Episode =   18, R_average =  -0.207, Position: [ -0.064,  0.008,  0.000]
# Episode =   19, R_average =  -0.204, Position: [ -0.064,  0.002,  0.000]
# Episode =   20, R_average =  -0.201, Position: [ -0.059, -0.002,  0.000]
# Episode =   21, R_average =  -0.198, Position: [ -0.053, -0.004,  0.000]
# Episode =   22, R_average =  -0.199, Position: [ -0.047, -0.002,  0.001]
# Episode =   23, R_average =  -0.199, Position: [ -0.041,  0.005,  0.002]
# Episode =   24, R_average =  -0.287, Position: [ -0.067,  0.032,  0.000]
# Episode =   25, R_average =  -0.188, Position: [ -0.030,  0.026,  0.000]
# Episode =   26, R_average =  -0.186, Position: [ -0.025,  0.031,  0.000]
# Episode =   27, R_average =  -0.180, Position: [ -0.020,  0.022,  0.000]
# Episode =   28, R_average =  -0.177, Position: [ -0.017,  0.020,  0.000]
# Episode =   29, R_average =  -0.175, Position: [ -0.026,  0.024,  0.000]
# Episode =   30, R_average =  -0.088, Position: [ -0.012,  0.005,  0.000]
# Episode =   31, R_average =  -0.088, Position: [ -0.013,  0.004,  0.000]
# Episode =   32, R_average =  -0.087, Position: [ -0.013,  0.004,  0.000]
# Episode =   33, R_average =  -0.087, Position: [ -0.013,  0.004,  0.000]
# Episode =   34, R_average =  -0.086, Position: [ -0.014,  0.003,  0.000]
# Episode =   35, R_average =  -0.086, Position: [ -0.014,  0.003,  0.000]
# Episode =   36, R_average =  -0.085, Position: [ -0.014,  0.002,  0.000]
# Episode =   37, R_average =  -0.084, Position: [ -0.015,  0.001,  0.000]
# Episode =   38, R_average =  -0.084, Position: [ -0.015,  0.001,  0.000]
# Episode =   39, R_average =  -0.083, Position: [ -0.015,  0.000,  0.000]
# Episode =   40, R_average =  -0.083, Position: [ -0.015, -0.000,  0.000]
# Episode =   41, R_average =  -0.082, Position: [ -0.016, -0.001,  0.000]
# Episode =   42, R_average =  -0.082, Position: [ -0.016, -0.001,  0.000]
# Episode =   43, R_average =  -0.081, Position: [ -0.016, -0.002,  0.000]
# Episode =   44, R_average =  -0.081, Position: [ -0.015, -0.002,  0.000]
# Episode =   45, R_average =  -0.080, Position: [ -0.015, -0.002,  0.000]
# Episode =   46, R_average =  -0.080, Position: [ -0.015, -0.002,  0.000]
# Episode =   47, R_average =  -0.079, Position: [ -0.015, -0.002,  0.000]
# Episode =   48, R_average =  -0.079, Position: [ -0.015, -0.001,  0.000]
# Episode =   49, R_average =  -0.078, Position: [ -0.014, -0.001,  0.000]
# Episode =   50, R_average =  -0.078, Position: [ -0.014, -0.001,  0.000]
# Episode =   51, R_average =  -0.077, Position: [ -0.014, -0.000,  0.000]
# Episode =   52, R_average =  -0.077, Position: [ -0.014, -0.000,  0.000]
# Episode =   53, R_average =  -0.076, Position: [ -0.014,  0.000,  0.000]
# Episode =   54, R_average =  -0.076, Position: [ -0.014,  0.001,  0.000]
# Episode =   55, R_average =  -0.076, Position: [ -0.013,  0.001,  0.000]
# Episode =   56, R_average =  -0.075, Position: [ -0.013,  0.002,  0.000]
# Episode =   57, R_average =  -0.075, Position: [ -0.013,  0.002,  0.000]
# Episode =   58, R_average =  -0.074, Position: [ -0.013,  0.002,  0.000]
# Episode =   59, R_average =  -0.074, Position: [ -0.013,  0.002,  0.000]
# Episode =   60, R_average =  -0.073, Position: [ -0.013,  0.002,  0.000]
# Episode =   61, R_average =  -0.073, Position: [ -0.013,  0.002,  0.000]
# Episode =   62, R_average =  -0.073, Position: [ -0.013,  0.001,  0.000]
# Episode =   63, R_average =  -0.072, Position: [ -0.013,  0.001,  0.000]
# Episode =   64, R_average =  -0.072, Position: [ -0.013,  0.001,  0.000]
# Episode =   65, R_average =  -0.071, Position: [ -0.013,  0.001,  0.000]
# Episode =   66, R_average =  -0.071, Position: [ -0.013,  0.001,  0.000]
# Episode =   67, R_average =  -0.071, Position: [ -0.013,  0.001,  0.000]
# Episode =   68, R_average =  -0.070, Position: [ -0.013,  0.001,  0.000]
# Episode =   69, R_average =  -0.070, Position: [ -0.013,  0.000,  0.000]
# Episode =   70, R_average =  -0.070, Position: [ -0.014,  0.000,  0.000]
# Episode =   71, R_average =  -0.069, Position: [ -0.014,  0.001,  0.000]
# Episode =   72, R_average =  -0.069, Position: [ -0.014,  0.001,  0.000]
# Episode =   73, R_average =  -0.068, Position: [ -0.014,  0.001,  0.000]
# Episode =   74, R_average =  -0.068, Position: [ -0.014,  0.001,  0.000]
# Episode =   75, R_average =  -0.068, Position: [ -0.014,  0.001,  0.000]
# Episode =   76, R_average =  -0.067, Position: [ -0.014,  0.001,  0.000]
# Episode =   77, R_average =  -0.067, Position: [ -0.014,  0.001,  0.000]
# Episode =   78, R_average =  -0.067, Position: [ -0.014,  0.001,  0.000]
# Episode =   79, R_average =  -0.066, Position: [ -0.014,  0.001,  0.000]
# Episode =   80, R_average =  -0.066, Position: [ -0.014,  0.002,  0.000]
# Episode =   81, R_average =  -0.066, Position: [ -0.014,  0.003,  0.000]
# Episode =   82, R_average =  -0.065, Position: [ -0.014,  0.003,  0.000]
# Episode =   83, R_average =  -0.065, Position: [ -0.014,  0.004,  0.000]
# Episode =   84, R_average =  -0.065, Position: [ -0.015,  0.005,  0.000]
# Episode =   85, R_average =  -0.064, Position: [ -0.015,  0.006,  0.000]
# Episode =   86, R_average =  -0.064, Position: [ -0.015,  0.007,  0.000]
# Episode =   87, R_average =  -0.125, Position: [ -0.119,  0.014,  0.000]
# Episode =   88, R_average =  -0.123, Position: [ -0.126,  0.039,  0.000]
# Episode =   89, R_average =  -0.122, Position: [ -0.123,  0.055,  0.000]
# Episode =   90, R_average =  -0.121, Position: [ -0.117,  0.062,  0.000]
# Episode =   91, R_average =  -0.125, Position: [ -0.109,  0.048,  0.000]
# Episode =   92, R_average =  -0.181, Position: [ -0.256,  0.053,  0.000]
# Episode =   93, R_average =  -0.181, Position: [ -0.203,  0.038,  0.000]
# Episode =   94, R_average =  -1.137, Position: [-13.535,  1.139,  0.000]
# Episode =   95, R_average =  -0.108, Position: [  0.020,  0.030,  0.000]
# Episode =   96, R_average =  -0.107, Position: [  0.027,  0.033,  0.000]
# Episode =   97, R_average =  -0.107, Position: [  0.031,  0.040,  0.000]
# Episode =   98, R_average =  -0.106, Position: [  0.030,  0.048,  0.000]
# Episode =   99, R_average =  -0.105, Position: [  0.024,  0.057,  0.000]
# Episode =  100, R_average =  -0.104, Position: [  0.012,  0.059,  0.000]
# Episode =  101, R_average =  -0.103, Position: [ -0.006,  0.053,  0.000]
# Episode =  102, R_average =  -0.153, Position: [ -0.108,  0.095,  0.000]
# Episode =  103, R_average =  -0.205, Position: [ -0.475, -0.024,  0.000]
# Episode =  104, R_average =  -0.401, Position: [  1.220, -0.350,  0.000]
# Episode =  105, R_average =  -0.095, Position: [  0.032,  0.021,  0.000]
# Episode =  106, R_average =  -0.094, Position: [  0.024,  0.028,  0.000]
# Episode =  107, R_average =  -0.048, Position: [  0.013,  0.001,  0.000]
# Episode =  108, R_average =  -0.048, Position: [  0.014,  0.001,  0.000]
# Episode =  109, R_average =  -0.047, Position: [  0.014,  0.000,  0.000]
# Episode =  110, R_average =  -0.047, Position: [  0.014,  0.000,  0.000]
# Episode =  111, R_average =  -0.047, Position: [  0.014,  0.000,  0.000]
# Episode =  112, R_average =  -0.047, Position: [  0.014, -0.000,  0.000]
# Episode =  113, R_average =  -0.047, Position: [  0.013, -0.000,  0.000]
# Episode =  114, R_average =  -0.047, Position: [  0.013, -0.001,  0.000]
# Episode =  115, R_average =  -0.046, Position: [  0.012, -0.001,  0.000]
# Episode =  116, R_average =  -0.046, Position: [  0.012, -0.001,  0.000]
# Episode =  117, R_average =  -0.046, Position: [  0.011, -0.002,  0.000]
# Episode =  118, R_average =  -0.046, Position: [  0.010, -0.002,  0.000]
# Episode =  119, R_average =  -0.046, Position: [  0.010, -0.002,  0.000]
# Episode =  120, R_average =  -0.046, Position: [  0.009, -0.002,  0.000]
# Episode =  121, R_average =  -0.045, Position: [  0.008, -0.003,  0.000]
# Episode =  122, R_average =  -0.045, Position: [  0.007, -0.003,  0.000]
# Episode =  123, R_average =  -0.045, Position: [  0.007, -0.003,  0.000]
# Episode =  124, R_average =  -0.045, Position: [  0.006, -0.003,  0.000]
# Episode =  125, R_average =  -0.045, Position: [  0.005, -0.003,  0.000]
# Episode =  126, R_average =  -0.045, Position: [  0.004, -0.003,  0.000]
# Episode =  127, R_average =  -0.045, Position: [  0.004, -0.004,  0.000]
# Episode =  128, R_average =  -0.044, Position: [  0.003, -0.004,  0.000]
# Episode =  129, R_average =  -0.044, Position: [  0.003, -0.004,  0.000]
# Episode =  130, R_average =  -0.044, Position: [  0.002, -0.004,  0.000]
# Episode =  131, R_average =  -0.044, Position: [  0.002, -0.004,  0.000]
# Episode =  132, R_average =  -0.044, Position: [  0.002, -0.005,  0.000]
# Episode =  133, R_average =  -0.044, Position: [  0.001, -0.005,  0.000]
# Episode =  134, R_average =  -0.043, Position: [  0.001, -0.005,  0.000]
# Episode =  135, R_average =  -0.043, Position: [ -0.000, -0.005,  0.000]
# Episode =  136, R_average =  -0.043, Position: [ -0.000, -0.006,  0.000]
# Episode =  137, R_average =  -0.043, Position: [ -0.001, -0.006,  0.000]
# Episode =  138, R_average =  -0.043, Position: [ -0.001, -0.006,  0.000]
# Episode =  139, R_average =  -0.043, Position: [ -0.002, -0.007,  0.000]
# Episode =  140, R_average =  -0.043, Position: [ -0.002, -0.007,  0.000]
# Episode =  141, R_average =  -0.042, Position: [ -0.002, -0.008,  0.000]
# Episode =  142, R_average =  -0.042, Position: [ -0.003, -0.008,  0.000]
# Episode =  143, R_average =  -0.042, Position: [ -0.003, -0.008,  0.000]
# Episode =  144, R_average =  -0.042, Position: [ -0.003, -0.009,  0.000]
# Episode =  145, R_average =  -0.042, Position: [ -0.004, -0.009,  0.000]
# Episode =  146, R_average =  -0.042, Position: [ -0.004, -0.009,  0.000]
# Episode =  147, R_average =  -0.042, Position: [ -0.004, -0.010,  0.000]
# Episode =  148, R_average =  -0.042, Position: [ -0.005, -0.010,  0.000]
# Episode =  149, R_average =  -0.041, Position: [ -0.005, -0.010,  0.000]
# Episode =  150, R_average =  -0.041, Position: [ -0.005, -0.011,  0.000]
# Episode =  151, R_average =  -0.041, Position: [ -0.005, -0.011,  0.000]
# Episode =  152, R_average =  -0.041, Position: [ -0.006, -0.011,  0.000]
# Episode =  153, R_average =  -0.041, Position: [ -0.006, -0.011,  0.000]
# Episode =  154, R_average =  -0.041, Position: [ -0.006, -0.011,  0.000]
# Episode =  155, R_average =  -0.079, Position: [ -0.008, -0.013,  0.000]
# Episode =  156, R_average =  -0.079, Position: [ -0.012, -0.013,  0.000]
# Episode =  157, R_average =  -0.078, Position: [ -0.015, -0.013,  0.000]
# Episode =  158, R_average =  -0.078, Position: [ -0.017, -0.013,  0.000]
# Episode =  159, R_average =  -0.078, Position: [ -0.018, -0.013,  0.000]
# Episode =  160, R_average =  -0.077, Position: [ -0.020, -0.013,  0.000]
# Episode =  161, R_average =  -0.077, Position: [ -0.021, -0.013,  0.000]
# Episode =  162, R_average =  -0.076, Position: [ -0.024, -0.013,  0.000]
# Episode =  163, R_average =  -0.076, Position: [ -0.025, -0.013,  0.000]
# Episode =  164, R_average =  -0.075, Position: [ -0.026, -0.013,  0.000]
# Episode =  165, R_average =  -0.075, Position: [ -0.027, -0.012,  0.000]
# Episode =  166, R_average =  -0.074, Position: [ -0.029, -0.012,  0.000]
# Episode =  167, R_average =  -0.074, Position: [ -0.029, -0.012,  0.000]
# Episode =  168, R_average =  -0.074, Position: [ -0.031, -0.012,  0.000]
# Episode =  169, R_average =  -0.073, Position: [ -0.031, -0.012,  0.000]
# Episode =  170, R_average =  -0.073, Position: [ -0.031, -0.011,  0.000]
# Episode =  171, R_average =  -0.072, Position: [ -0.033, -0.011,  0.000]
# Episode =  172, R_average =  -0.072, Position: [ -0.033, -0.010,  0.000]
# Episode =  173, R_average =  -0.071, Position: [ -0.033, -0.010,  0.000]
# Episode =  174, R_average =  -0.071, Position: [ -0.034, -0.010,  0.000]
# Episode =  175, R_average =  -0.071, Position: [ -0.034, -0.010,  0.000]
# Episode =  176, R_average =  -0.070, Position: [ -0.033, -0.010,  0.000]
# Episode =  177, R_average =  -0.070, Position: [ -0.035, -0.010,  0.000]
# Episode =  178, R_average =  -0.070, Position: [ -0.036, -0.010,  0.000]
# Episode =  179, R_average =  -0.069, Position: [ -0.034, -0.010,  0.000]
# Episode =  180, R_average =  -0.069, Position: [ -0.036, -0.010,  0.000]
# Episode =  181, R_average =  -0.068, Position: [ -0.036, -0.011,  0.000]
# Episode =  182, R_average =  -0.068, Position: [ -0.037, -0.011,  0.000]
# Episode =  183, R_average =  -0.068, Position: [ -0.035, -0.012,  0.000]
# Episode =  184, R_average =  -0.067, Position: [ -0.037, -0.014,  0.000]
# Episode =  185, R_average =  -0.034, Position: [ -0.010, -0.010,  0.000]
# Episode =  186, R_average =  -0.034, Position: [ -0.010, -0.009,  0.000]
# Episode =  187, R_average =  -0.034, Position: [ -0.010, -0.009,  0.000]
# Episode =  188, R_average =  -0.034, Position: [ -0.010, -0.008,  0.000]
# Episode =  189, R_average =  -0.034, Position: [ -0.009, -0.008,  0.000]
# Episode =  190, R_average =  -0.034, Position: [ -0.009, -0.007,  0.000]
# Episode =  191, R_average =  -0.034, Position: [ -0.009, -0.006,  0.000]
# Episode =  192, R_average =  -0.034, Position: [ -0.009, -0.006,  0.000]
# Episode =  193, R_average =  -0.034, Position: [ -0.009, -0.005,  0.000]
# Episode =  194, R_average =  -0.033, Position: [ -0.009, -0.004,  0.000]
# Episode =  195, R_average =  -0.033, Position: [ -0.009, -0.004,  0.000]
# Episode =  196, R_average =  -0.033, Position: [ -0.009, -0.003,  0.000]
# Episode =  197, R_average =  -0.033, Position: [ -0.009, -0.003,  0.000]
# Episode =  198, R_average =  -0.033, Position: [ -0.009, -0.002,  0.000]
# Episode =  199, R_average =  -0.033, Position: [ -0.009, -0.002,  0.000]
# Episode =  200, R_average =  -0.033, Position: [ -0.009, -0.001,  0.000]
# Episode =  201, R_average =  -0.033, Position: [ -0.009, -0.001,  0.000]
# Episode =  202, R_average =  -0.033, Position: [ -0.009, -0.000,  0.000]
# Episode =  203, R_average =  -0.033, Position: [ -0.009,  0.001,  0.000]
# Episode =  204, R_average =  -0.033, Position: [ -0.009,  0.002,  0.000]
# Episode =  205, R_average =  -0.032, Position: [ -0.009,  0.003,  0.000]
# Episode =  206, R_average =  -0.032, Position: [ -0.009,  0.004,  0.000]
# Episode =  207, R_average =  -0.032, Position: [ -0.008,  0.005,  0.000]
# Episode =  208, R_average =  -0.032, Position: [ -0.008,  0.007,  0.000]
# Episode =  209, R_average =  -0.032, Position: [ -0.008,  0.008,  0.000]
# Episode =  210, R_average =  -0.032, Position: [ -0.008,  0.010,  0.000]
# Episode =  211, R_average =  -0.032, Position: [ -0.008,  0.010,  0.000]
# Episode =  212, R_average =  -0.063, Position: [ -0.026,  0.035,  0.000]
# Episode =  213, R_average =  -0.062, Position: [ -0.026,  0.049,  0.000]
# Episode =  214, R_average =  -0.064, Position: [ -0.026,  0.045,  0.000]
# Episode =  215, R_average =  -0.094, Position: [ -0.041,  0.050,  0.000]
# Episode =  216, R_average =  -0.093, Position: [ -0.036,  0.014,  0.000]
# Episode =  217, R_average =  -0.093, Position: [ -0.034,  0.003,  0.000]
# Episode =  218, R_average =  -0.092, Position: [ -0.034,  0.001,  0.000]
# Episode =  219, R_average =  -0.091, Position: [ -0.035,  0.000,  0.000]
# Episode =  220, R_average =  -0.091, Position: [ -0.037, -0.000,  0.000]
# Episode =  221, R_average =  -0.090, Position: [ -0.035, -0.000,  0.000]
# Episode =  222, R_average =  -0.061, Position: [ -0.022, -0.000,  0.000]
# Episode =  223, R_average =  -0.061, Position: [ -0.022, -0.000,  0.000]
# Episode =  224, R_average =  -0.060, Position: [ -0.023, -0.000,  0.000]
# Episode =  225, R_average =  -0.060, Position: [ -0.023, -0.000,  0.000]
# Episode =  226, R_average =  -0.060, Position: [ -0.024, -0.000,  0.000]
# Episode =  227, R_average =  -0.060, Position: [ -0.022, -0.000,  0.000]
# Episode =  228, R_average =  -0.059, Position: [ -0.023, -0.000,  0.000]
# Episode =  229, R_average =  -0.059, Position: [ -0.023, -0.000,  0.000]
# Episode =  230, R_average =  -0.059, Position: [ -0.022, -0.000,  0.000]
# Episode =  231, R_average =  -0.058, Position: [ -0.023, -0.000,  0.000]
# Episode =  232, R_average =  -0.058, Position: [ -0.023, -0.000,  0.000]
# Episode =  233, R_average =  -0.058, Position: [ -0.023, -0.000,  0.000]
# Episode =  234, R_average =  -0.058, Position: [ -0.023, -0.000,  0.000]
# Episode =  235, R_average =  -0.057, Position: [ -0.023, -0.000,  0.000]
# Episode =  236, R_average =  -0.057, Position: [ -0.024, -0.000,  0.000]
# Episode =  237, R_average =  -0.057, Position: [ -0.024, -0.000,  0.000]
# Episode =  238, R_average =  -0.057, Position: [ -0.023, -0.000,  0.000]
# Episode =  239, R_average =  -0.057, Position: [ -0.023, -0.000,  0.000]
# Episode =  240, R_average =  -0.056, Position: [ -0.024, -0.000,  0.000]
# Episode =  241, R_average =  -0.056, Position: [ -0.024, -0.000,  0.000]
# Episode =  242, R_average =  -0.056, Position: [ -0.024, -0.000,  0.000]
# Episode =  243, R_average =  -0.056, Position: [ -0.024, -0.000,  0.000]
# Episode =  244, R_average =  -0.055, Position: [ -0.024, -0.000,  0.000]
# Episode =  245, R_average =  -0.055, Position: [ -0.024, -0.000,  0.000]
# Episode =  246, R_average =  -0.055, Position: [ -0.024, -0.000,  0.000]
# Episode =  247, R_average =  -0.055, Position: [ -0.024, -0.000,  0.000]
# Episode =  248, R_average =  -0.054, Position: [ -0.024, -0.000,  0.000]
# Episode =  249, R_average =  -0.054, Position: [ -0.023, -0.000,  0.000]
# Episode =  250, R_average =  -0.054, Position: [ -0.024, -0.000,  0.000]
# Episode =  251, R_average =  -0.054, Position: [ -0.024, -0.000,  0.000]
# Episode =  252, R_average =  -0.054, Position: [ -0.024, -0.000,  0.000]
# Episode =  253, R_average =  -0.053, Position: [ -0.024, -0.000,  0.000]
# Episode =  254, R_average =  -0.053, Position: [ -0.024, -0.000,  0.000]
# Episode =  255, R_average =  -0.053, Position: [ -0.024, -0.000,  0.000]
# Episode =  256, R_average =  -0.053, Position: [ -0.024, -0.000,  0.000]
# Episode =  257, R_average =  -0.052, Position: [ -0.023, -0.000,  0.000]
# Episode =  258, R_average =  -0.052, Position: [ -0.024, -0.000,  0.000]
# Episode =  259, R_average =  -0.052, Position: [ -0.024, -0.000,  0.000]
# Episode =  260, R_average =  -0.052, Position: [ -0.025, -0.000,  0.000]
# Episode =  261, R_average =  -0.052, Position: [ -0.023, -0.000,  0.000]
# Episode =  262, R_average =  -0.051, Position: [ -0.025, -0.000,  0.000]
# Episode =  263, R_average =  -0.051, Position: [ -0.024, -0.000,  0.000]
# Episode =  264, R_average =  -0.051, Position: [ -0.024, -0.000,  0.000]
# Episode =  265, R_average =  -0.051, Position: [ -0.024, -0.000,  0.000]
# Episode =  266, R_average =  -0.051, Position: [ -0.024, -0.000,  0.000]
# Episode =  267, R_average =  -0.050, Position: [ -0.023, -0.000,  0.000]
# Episode =  268, R_average =  -0.050, Position: [ -0.024, -0.000,  0.000]
# Episode =  269, R_average =  -0.050, Position: [ -0.025, -0.000,  0.000]
# Episode =  270, R_average =  -0.050, Position: [ -0.024, -0.000,  0.000]
# Episode =  271, R_average =  -0.050, Position: [ -0.025, -0.000,  0.000]
# Episode =  272, R_average =  -0.050, Position: [ -0.024, -0.000,  0.000]
# Episode =  273, R_average =  -0.049, Position: [ -0.024, -0.000,  0.000]
# Episode =  274, R_average =  -0.049, Position: [ -0.024, -0.000,  0.000]
# Episode =  275, R_average =  -0.049, Position: [ -0.025, -0.000,  0.000]
# Episode =  276, R_average =  -0.049, Position: [ -0.025, -0.000,  0.000]
# Episode =  277, R_average =  -0.049, Position: [ -0.024, -0.000,  0.000]
# Episode =  278, R_average =  -0.048, Position: [ -0.024, -0.000,  0.000]
# Episode =  279, R_average =  -0.048, Position: [ -0.025, -0.000,  0.000]
# Episode =  280, R_average =  -0.048, Position: [ -0.024, -0.000,  0.000]
# Episode =  281, R_average =  -0.048, Position: [ -0.025, -0.000,  0.000]
# Episode =  282, R_average =  -0.048, Position: [ -0.025, -0.000,  0.000]
# Episode =  283, R_average =  -0.048, Position: [ -0.025, -0.000,  0.000]
# Episode =  284, R_average =  -0.047, Position: [ -0.024, -0.000,  0.000]
# Episode =  285, R_average =  -0.047, Position: [ -0.024, -0.000,  0.000]
# Episode =  286, R_average =  -0.047, Position: [ -0.024, -0.000,  0.000]
# Episode =  287, R_average =  -0.047, Position: [ -0.025, -0.000,  0.000]
# Episode =  288, R_average =  -0.047, Position: [ -0.025, -0.000,  0.000]
# Episode =  289, R_average =  -0.047, Position: [ -0.024, -0.000,  0.000]
# Episode =  290, R_average =  -0.046, Position: [ -0.025, -0.000,  0.000]
# Episode =  291, R_average =  -0.046, Position: [ -0.025, -0.000,  0.000]
# Episode =  292, R_average =  -0.046, Position: [ -0.025, -0.000,  0.000]
# Episode =  293, R_average =  -0.046, Position: [ -0.025, -0.000,  0.000]
# Episode =  294, R_average =  -0.046, Position: [ -0.024, -0.000,  0.000]
# Episode =  295, R_average =  -0.046, Position: [ -0.024, -0.000,  0.000]
# Episode =  296, R_average =  -0.045, Position: [ -0.024, -0.000,  0.000]
# Episode =  297, R_average =  -0.045, Position: [ -0.025, -0.000,  0.000]
# Episode =  298, R_average =  -0.045, Position: [ -0.025, -0.000,  0.000]
# Episode =  299, R_average =  -0.045, Position: [ -0.025, -0.000,  0.000]
# Episode =  300, R_average =  -0.045, Position: [ -0.025, -0.000,  0.000]
# Episode =  301, R_average =  -0.045, Position: [ -0.025, -0.000,  0.000]
# Episode =  302, R_average =  -0.045, Position: [ -0.025, -0.000,  0.000]
# Episode =  303, R_average =  -0.044, Position: [ -0.026, -0.000,  0.000]
# Episode =  304, R_average =  -0.044, Position: [ -0.025, -0.000,  0.000]
# Episode =  305, R_average =  -0.044, Position: [ -0.025, -0.000,  0.000]
# Episode =  306, R_average =  -0.044, Position: [ -0.025, -0.000,  0.000]
# Episode =  307, R_average =  -0.044, Position: [ -0.026, -0.000,  0.000]
# Episode =  308, R_average =  -0.044, Position: [ -0.025, -0.000,  0.000]
# Episode =  309, R_average =  -0.044, Position: [ -0.024, -0.000,  0.000]
# Episode =  310, R_average =  -0.043, Position: [ -0.026, -0.000,  0.000]
# Episode =  311, R_average =  -0.043, Position: [ -0.026, -0.000,  0.000]
# Episode =  312, R_average =  -0.043, Position: [ -0.025, -0.000,  0.000]
# Episode =  313, R_average =  -0.043, Position: [ -0.025, -0.000,  0.000]
# Episode =  314, R_average =  -0.043, Position: [ -0.025, -0.000,  0.000]
# Episode =  315, R_average =  -0.043, Position: [ -0.025, -0.000,  0.000]
# Episode =  316, R_average =  -0.043, Position: [ -0.025, -0.000,  0.000]
# Episode =  317, R_average =  -0.042, Position: [ -0.026,  0.000,  0.000]
# Episode =  318, R_average =  -0.042, Position: [ -0.024, -0.000,  0.000]
# Episode =  319, R_average =  -0.042, Position: [ -0.026, -0.000,  0.000]
# Episode =  320, R_average =  -0.042, Position: [ -0.025, -0.000,  0.000]
# Episode =  321, R_average =  -0.042, Position: [ -0.024, -0.000,  0.000]
# Episode =  322, R_average =  -0.042, Position: [ -0.026, -0.000,  0.000]
# Episode =  323, R_average =  -0.042, Position: [ -0.026, -0.000,  0.000]
# Episode =  324, R_average =  -0.041, Position: [ -0.024, -0.000,  0.000]
# Episode =  325, R_average =  -0.041, Position: [ -0.026, -0.000,  0.000]
# Episode =  326, R_average =  -0.041, Position: [ -0.025, -0.000,  0.000]
# Episode =  327, R_average =  -0.041, Position: [ -0.026, -0.000,  0.000]
# Episode =  328, R_average =  -0.041, Position: [ -0.025, -0.000,  0.000]
# Episode =  329, R_average =  -0.041, Position: [ -0.024, -0.000,  0.000]
# Episode =  330, R_average =  -0.041, Position: [ -0.025, -0.000,  0.000]
# Episode =  331, R_average =  -0.041, Position: [ -0.025, -0.000,  0.000]
# Episode =  332, R_average =  -0.040, Position: [ -0.026, -0.000,  0.000]
# Episode =  333, R_average =  -0.040, Position: [ -0.025, -0.000,  0.000]
# Episode =  334, R_average =  -0.040, Position: [ -0.025, -0.000,  0.000]
# Episode =  335, R_average =  -0.040, Position: [ -0.026, -0.000,  0.000]
# Episode =  336, R_average =  -0.040, Position: [ -0.025, -0.000,  0.000]
# Episode =  337, R_average =  -0.040, Position: [ -0.025, -0.000,  0.000]
# Episode =  338, R_average =  -0.040, Position: [ -0.025, -0.000,  0.000]
# Episode =  339, R_average =  -0.040, Position: [ -0.025, -0.000,  0.000]
# Episode =  340, R_average =  -0.039, Position: [ -0.025, -0.000,  0.000]
# Episode =  341, R_average =  -0.039, Position: [ -0.026, -0.000,  0.000]
# Episode =  342, R_average =  -0.039, Position: [ -0.026, -0.000,  0.000]
# Episode =  343, R_average =  -0.039, Position: [ -0.025, -0.000,  0.000]
# Episode =  344, R_average =  -0.039, Position: [ -0.025, -0.000,  0.000]
# Episode =  345, R_average =  -0.039, Position: [ -0.025,  0.000,  0.000]
# Episode =  346, R_average =  -0.039, Position: [ -0.025,  0.000,  0.000]
# Episode =  347, R_average =  -0.039, Position: [ -0.025,  0.000,  0.000]
# Episode =  348, R_average =  -0.039, Position: [ -0.025, -0.000,  0.000]
# Episode =  349, R_average =  -0.038, Position: [ -0.025, -0.000,  0.000]
# Episode =  350, R_average =  -0.038, Position: [ -0.025, -0.000,  0.000]
# Episode =  351, R_average =  -0.038, Position: [ -0.026, -0.000,  0.000]
# Episode =  352, R_average =  -0.038, Position: [ -0.026, -0.000,  0.000]
# Episode =  353, R_average =  -0.038, Position: [ -0.025, -0.000,  0.000]
# Episode =  354, R_average =  -0.038, Position: [ -0.025, -0.000,  0.000]
# Episode =  355, R_average =  -0.038, Position: [ -0.025, -0.000,  0.000]
# Episode =  356, R_average =  -0.038, Position: [ -0.026, -0.000,  0.000]
# Episode =  357, R_average =  -0.038, Position: [ -0.026, -0.000,  0.000]
# Episode =  358, R_average =  -0.037, Position: [ -0.025, -0.000,  0.000]
# Episode =  359, R_average =  -0.037, Position: [ -0.025,  0.000,  0.000]
# Episode =  360, R_average =  -0.037, Position: [ -0.025,  0.000,  0.000]
# Episode =  361, R_average =  -0.037, Position: [ -0.026, -0.000,  0.000]
# Episode =  362, R_average =  -0.037, Position: [ -0.024, -0.000,  0.000]
# Episode =  363, R_average =  -0.037, Position: [ -0.025, -0.000,  0.000]
# Episode =  364, R_average =  -0.037, Position: [ -0.025, -0.000,  0.000]
# Episode =  365, R_average =  -0.037, Position: [ -0.027, -0.000,  0.000]
# Episode =  366, R_average =  -0.037, Position: [ -0.026, -0.000,  0.000]
# Episode =  367, R_average =  -0.037, Position: [ -0.026, -0.000,  0.000]
# Episode =  368, R_average =  -0.036, Position: [ -0.025, -0.000,  0.000]
# Episode =  369, R_average =  -0.036, Position: [ -0.026, -0.000,  0.000]
# Episode =  370, R_average =  -0.036, Position: [ -0.026, -0.000,  0.000]
# Episode =  371, R_average =  -0.036, Position: [ -0.025,  0.000,  0.000]
# Episode =  372, R_average =  -0.036, Position: [ -0.025, -0.000,  0.000]
# Episode =  373, R_average =  -0.036, Position: [ -0.026, -0.000,  0.000]
# Episode =  374, R_average =  -0.036, Position: [ -0.026, -0.000,  0.000]
# Episode =  375, R_average =  -0.036, Position: [ -0.025, -0.000,  0.000]
# Episode =  376, R_average =  -0.036, Position: [ -0.025, -0.000,  0.000]
# Episode =  377, R_average =  -0.036, Position: [ -0.025, -0.000,  0.000]
# Episode =  378, R_average =  -0.035, Position: [ -0.025, -0.000,  0.000]
# Episode =  379, R_average =  -0.035, Position: [ -0.026, -0.000,  0.000]
# Episode =  380, R_average =  -0.035, Position: [ -0.025, -0.000,  0.000]
# Episode =  381, R_average =  -0.035, Position: [ -0.026,  0.000,  0.000]
# Episode =  382, R_average =  -0.035, Position: [ -0.025,  0.000,  0.000]
# Episode =  383, R_average =  -0.035, Position: [ -0.025, -0.000,  0.000]
# Episode =  384, R_average =  -0.035, Position: [ -0.025, -0.000,  0.000]
# Episode =  385, R_average =  -0.035, Position: [ -0.025,  0.000,  0.000]
# Episode =  386, R_average =  -0.035, Position: [ -0.025, -0.000,  0.000]
# Episode =  387, R_average =  -0.035, Position: [ -0.025,  0.000,  0.000]
# Episode =  388, R_average =  -0.035, Position: [ -0.026, -0.000,  0.000]
# Episode =  389, R_average =  -0.034, Position: [ -0.024, -0.000,  0.000]
# Episode =  390, R_average =  -0.034, Position: [ -0.025, -0.000,  0.000]
# Episode =  391, R_average =  -0.034, Position: [ -0.025, -0.000,  0.000]
# Episode =  392, R_average =  -0.034, Position: [ -0.025, -0.000,  0.000]
# Episode =  393, R_average =  -0.034, Position: [ -0.026,  0.000,  0.000]
# Episode =  394, R_average =  -0.034, Position: [ -0.026,  0.000,  0.000]
# Episode =  395, R_average =  -0.034, Position: [ -0.024, -0.000,  0.000]
# Episode =  396, R_average =  -0.034, Position: [ -0.025, -0.000,  0.000]
# Episode =  397, R_average =  -0.034, Position: [ -0.026, -0.000,  0.000]
# Episode =  398, R_average =  -0.034, Position: [ -0.026, -0.000,  0.000]
# Episode =  399, R_average =  -0.034, Position: [ -0.025, -0.000,  0.000]
# Episode =  400, R_average =  -0.034, Position: [ -0.025, -0.000,  0.000]
# Episode =  401, R_average =  -0.033, Position: [ -0.026, -0.000,  0.000]
# Episode =  402, R_average =  -0.033, Position: [ -0.026,  0.000,  0.000]
# Episode =  403, R_average =  -0.033, Position: [ -0.026, -0.000,  0.000]
# Episode =  404, R_average =  -0.033, Position: [ -0.026,  0.000,  0.000]
# Episode =  405, R_average =  -0.033, Position: [ -0.026,  0.000,  0.000]
# Episode =  406, R_average =  -0.033, Position: [ -0.025, -0.000,  0.000]
# Episode =  407, R_average =  -0.033, Position: [ -0.025, -0.000,  0.000]
# Episode =  408, R_average =  -0.033, Position: [ -0.026,  0.000,  0.000]
# Episode =  409, R_average =  -0.033, Position: [ -0.025,  0.000,  0.000]
# Episode =  410, R_average =  -0.033, Position: [ -0.025, -0.000,  0.000]
# Episode =  411, R_average =  -0.033, Position: [ -0.025,  0.000,  0.000]
# Episode =  412, R_average =  -0.033, Position: [ -0.027,  0.000,  0.000]
# Episode =  413, R_average =  -0.032, Position: [ -0.026,  0.000,  0.000]
# Episode =  414, R_average =  -0.032, Position: [ -0.026,  0.000,  0.000]
# Episode =  415, R_average =  -0.032, Position: [ -0.025, -0.000,  0.000]
# Episode =  416, R_average =  -0.032, Position: [ -0.026, -0.000,  0.000]
# Episode =  417, R_average =  -0.032, Position: [ -0.026, -0.000,  0.000]
# Episode =  418, R_average =  -0.032, Position: [ -0.025, -0.000,  0.000]
# Episode =  419, R_average =  -0.032, Position: [ -0.026, -0.000,  0.000]
# Episode =  420, R_average =  -0.032, Position: [ -0.025,  0.000,  0.000]
# Episode =  421, R_average =  -0.032, Position: [ -0.026, -0.000,  0.000]
# Episode =  422, R_average =  -0.032, Position: [ -0.025, -0.000,  0.000]
# Episode =  423, R_average =  -0.032, Position: [ -0.025,  0.000,  0.000]
# Episode =  424, R_average =  -0.032, Position: [ -0.025, -0.000,  0.000]
# Episode =  425, R_average =  -0.032, Position: [ -0.026,  0.000,  0.000]
# Episode =  426, R_average =  -0.031, Position: [ -0.025,  0.000,  0.000]
# Episode =  427, R_average =  -0.031, Position: [ -0.025, -0.000,  0.000]
# Episode =  428, R_average =  -0.031, Position: [ -0.025,  0.000,  0.000]
# Episode =  429, R_average =  -0.031, Position: [ -0.026, -0.000,  0.000]
# Episode =  430, R_average =  -0.031, Position: [ -0.025,  0.000,  0.000]
# Episode =  431, R_average =  -0.031, Position: [ -0.025,  0.000,  0.000]
# Episode =  432, R_average =  -0.031, Position: [ -0.026, -0.000,  0.000]
# Episode =  433, R_average =  -0.031, Position: [ -0.025,  0.000,  0.000]
# Episode =  434, R_average =  -0.031, Position: [ -0.025,  0.000,  0.000]
# Episode =  435, R_average =  -0.031, Position: [ -0.026,  0.000,  0.000]
# Episode =  436, R_average =  -0.031, Position: [ -0.025,  0.000,  0.000]
# Episode =  437, R_average =  -0.031, Position: [ -0.025, -0.000,  0.000]
# Episode =  438, R_average =  -0.031, Position: [ -0.025,  0.000,  0.000]
# Episode =  439, R_average =  -0.030, Position: [ -0.025, -0.000,  0.000]
# Episode =  440, R_average =  -0.030, Position: [ -0.025, -0.000,  0.000]
# Episode =  441, R_average =  -0.030, Position: [ -0.025,  0.000,  0.000]
# Episode =  442, R_average =  -0.030, Position: [ -0.025,  0.000,  0.000]
# Episode =  443, R_average =  -0.030, Position: [ -0.026, -0.000,  0.000]
# Episode =  444, R_average =  -0.030, Position: [ -0.025, -0.000,  0.000]
# Episode =  445, R_average =  -0.030, Position: [ -0.026, -0.000,  0.000]
# Episode =  446, R_average =  -0.030, Position: [ -0.026,  0.000,  0.000]
# Episode =  447, R_average =  -0.030, Position: [ -0.026,  0.000,  0.000]
# Episode =  448, R_average =  -0.030, Position: [ -0.026, -0.000,  0.000]
# Episode =  449, R_average =  -0.030, Position: [ -0.024,  0.000,  0.000]
# Episode =  450, R_average =  -0.030, Position: [ -0.025, -0.000,  0.000]
# Episode =  451, R_average =  -0.030, Position: [ -0.025,  0.000,  0.000]
# Episode =  452, R_average =  -0.030, Position: [ -0.025,  0.000,  0.000]
# Episode =  453, R_average =  -0.030, Position: [ -0.026, -0.000,  0.000]
# Episode =  454, R_average =  -0.029, Position: [ -0.025,  0.000,  0.000]
# Episode =  455, R_average =  -0.029, Position: [ -0.026,  0.000,  0.000]
# Episode =  456, R_average =  -0.029, Position: [ -0.026,  0.000,  0.000]
# Episode =  457, R_average =  -0.029, Position: [ -0.026,  0.000,  0.000]
# Episode =  458, R_average =  -0.029, Position: [ -0.025, -0.000,  0.000]
# Episode =  459, R_average =  -0.029, Position: [ -0.025, -0.000,  0.000]
# Episode =  460, R_average =  -0.029, Position: [ -0.025,  0.000,  0.000]
# Episode =  461, R_average =  -0.029, Position: [ -0.025, -0.000,  0.000]
# Episode =  462, R_average =  -0.029, Position: [ -0.025,  0.000,  0.000]
# Episode =  463, R_average =  -0.029, Position: [ -0.025, -0.000,  0.000]
# Episode =  464, R_average =  -0.029, Position: [ -0.025,  0.000,  0.000]
# Episode =  465, R_average =  -0.029, Position: [ -0.025,  0.000,  0.000]
# Episode =  466, R_average =  -0.029, Position: [ -0.026, -0.000,  0.000]
# Episode =  467, R_average =  -0.029, Position: [ -0.027, -0.000,  0.000]
# Episode =  468, R_average =  -0.029, Position: [ -0.026,  0.000,  0.000]
# Episode =  469, R_average =  -0.029, Position: [ -0.026, -0.000,  0.000]
# Episode =  470, R_average =  -0.028, Position: [ -0.026,  0.000,  0.000]
# Episode =  471, R_average =  -0.028, Position: [ -0.025, -0.000,  0.000]
# Episode =  472, R_average =  -0.028, Position: [ -0.024, -0.000,  0.000]
# Episode =  473, R_average =  -0.028, Position: [ -0.025, -0.000,  0.000]
# Episode =  474, R_average =  -0.028, Position: [ -0.026, -0.000,  0.000]
# Episode =  475, R_average =  -0.028, Position: [ -0.027,  0.000,  0.000]
# Episode =  476, R_average =  -0.028, Position: [ -0.026,  0.000,  0.000]
# Episode =  477, R_average =  -0.028, Position: [ -0.026,  0.000,  0.000]
# Episode =  478, R_average =  -0.028, Position: [ -0.026, -0.000,  0.000]
# Episode =  479, R_average =  -0.028, Position: [ -0.025, -0.000,  0.000]
# Episode =  480, R_average =  -0.028, Position: [ -0.026,  0.000,  0.000]
# Episode =  481, R_average =  -0.028, Position: [ -0.025, -0.000,  0.000]
# Episode =  482, R_average =  -0.028, Position: [ -0.026,  0.000,  0.000]
# Episode =  483, R_average =  -0.028, Position: [ -0.025,  0.000,  0.000]
# Episode =  484, R_average =  -0.028, Position: [ -0.026,  0.000,  0.000]
# Episode =  485, R_average =  -0.028, Position: [ -0.026, -0.000,  0.000]
# Episode =  486, R_average =  -0.028, Position: [ -0.025, -0.000,  0.000]
# Episode =  487, R_average =  -0.027, Position: [ -0.025, -0.000,  0.000]
# Episode =  488, R_average =  -0.027, Position: [ -0.025, -0.000,  0.000]
# Episode =  489, R_average =  -0.027, Position: [ -0.026,  0.000,  0.000]
# Episode =  490, R_average =  -0.027, Position: [ -0.025,  0.000,  0.000]
# Episode =  491, R_average =  -0.027, Position: [ -0.025, -0.000,  0.000]
# Episode =  492, R_average =  -0.027, Position: [ -0.025, -0.000,  0.000]
# Episode =  493, R_average =  -0.027, Position: [ -0.025,  0.000,  0.000]
# Episode =  494, R_average =  -0.027, Position: [ -0.026, -0.000,  0.000]
# Episode =  495, R_average =  -0.027, Position: [ -0.025,  0.000,  0.000]
# Episode =  496, R_average =  -0.027, Position: [ -0.025, -0.000,  0.000]
# Episode =  497, R_average =  -0.027, Position: [ -0.026,  0.000,  0.000]
# Episode =  498, R_average =  -0.027, Position: [ -0.026, -0.000,  0.000]
# Episode =  499, R_average =  -0.027, Position: [ -0.026,  0.000,  0.000]
# Episode =  500, R_average =  -0.027, Position: [ -0.025,  0.000,  0.000]
# Episode =  501, R_average =  -0.027, Position: [ -0.026,  0.000,  0.000]
# Episode =  502, R_average =  -0.027, Position: [ -0.025, -0.000,  0.000]
# Episode =  503, R_average =  -0.027, Position: [ -0.025,  0.000,  0.000]
# Episode =  504, R_average =  -0.027, Position: [ -0.026,  0.000,  0.000]
# Episode =  505, R_average =  -0.026, Position: [ -0.025,  0.000,  0.000]
# Episode =  506, R_average =  -0.026, Position: [ -0.025, -0.000,  0.000]
# Episode =  507, R_average =  -0.026, Position: [ -0.026, -0.000,  0.000]
# Episode =  508, R_average =  -0.026, Position: [ -0.025,  0.000,  0.000]
# Episode =  509, R_average =  -0.026, Position: [ -0.024,  0.000,  0.000]
# Episode =  510, R_average =  -0.026, Position: [ -0.025, -0.000,  0.000]
# Episode =  511, R_average =  -0.026, Position: [ -0.025, -0.000,  0.000]
# Episode =  512, R_average =  -0.026, Position: [ -0.025, -0.000,  0.000]
# Episode =  513, R_average =  -0.026, Position: [ -0.026,  0.000,  0.000]
# Episode =  514, R_average =  -0.026, Position: [ -0.026, -0.000,  0.000]
# Episode =  515, R_average =  -0.026, Position: [ -0.026, -0.000,  0.000]
# Episode =  516, R_average =  -0.026, Position: [ -0.025, -0.000,  0.000]
# Episode =  517, R_average =  -0.026, Position: [ -0.026, -0.000,  0.000]
# Episode =  518, R_average =  -0.026, Position: [ -0.025, -0.000,  0.000]
# Episode =  519, R_average =  -0.026, Position: [ -0.025,  0.000,  0.000]
# Episode =  520, R_average =  -0.026, Position: [ -0.025,  0.000,  0.000]
# Episode =  521, R_average =  -0.026, Position: [ -0.025,  0.000,  0.000]
# Episode =  522, R_average =  -0.026, Position: [ -0.026, -0.000,  0.000]
# Episode =  523, R_average =  -0.026, Position: [ -0.026, -0.000,  0.000]
# Episode =  524, R_average =  -0.026, Position: [ -0.025, -0.000,  0.000]
# Episode =  525, R_average =  -0.025, Position: [ -0.026,  0.000,  0.000]
# Episode =  526, R_average =  -0.025, Position: [ -0.026, -0.000,  0.000]
# Episode =  527, R_average =  -0.025, Position: [ -0.025,  0.000,  0.000]
# Episode =  528, R_average =  -0.025, Position: [ -0.025, -0.000,  0.000]
# Episode =  529, R_average =  -0.025, Position: [ -0.025,  0.000,  0.000]
# Episode =  530, R_average =  -0.025, Position: [ -0.025, -0.000,  0.000]
# Episode =  531, R_average =  -0.025, Position: [ -0.025,  0.000,  0.000]
# Episode =  532, R_average =  -0.025, Position: [ -0.025,  0.000,  0.000]
# Episode =  533, R_average =  -0.025, Position: [ -0.026, -0.000,  0.000]
# Episode =  534, R_average =  -0.025, Position: [ -0.025, -0.000,  0.000]
# Episode =  535, R_average =  -0.025, Position: [ -0.026,  0.000,  0.000]
# Episode =  536, R_average =  -0.025, Position: [ -0.025, -0.000,  0.000]
# Episode =  537, R_average =  -0.025, Position: [ -0.026,  0.000,  0.000]
# Episode =  538, R_average =  -0.025, Position: [ -0.026, -0.000,  0.000]
# Episode =  539, R_average =  -0.025, Position: [ -0.025, -0.000,  0.000]
# Episode =  540, R_average =  -0.025, Position: [ -0.025, -0.000,  0.000]
# Episode =  541, R_average =  -0.025, Position: [ -0.025, -0.000,  0.000]
# Episode =  542, R_average =  -0.025, Position: [ -0.025, -0.000,  0.000]
# Episode =  543, R_average =  -0.025, Position: [ -0.025, -0.000,  0.000]
# Episode =  544, R_average =  -0.025, Position: [ -0.026,  0.000,  0.000]
# Episode =  545, R_average =  -0.025, Position: [ -0.026,  0.000,  0.000]
# Episode =  546, R_average =  -0.024, Position: [ -0.026, -0.000,  0.000]
# Episode =  547, R_average =  -0.024, Position: [ -0.026, -0.000,  0.000]
# Episode =  548, R_average =  -0.024, Position: [ -0.026,  0.000,  0.000]
# Episode =  549, R_average =  -0.024, Position: [ -0.025, -0.000,  0.000]
# Episode =  550, R_average =  -0.024, Position: [ -0.026,  0.000,  0.000]
# Episode =  551, R_average =  -0.024, Position: [ -0.026, -0.000,  0.000]
# Episode =  552, R_average =  -0.024, Position: [ -0.025, -0.000,  0.000]
# Episode =  553, R_average =  -0.024, Position: [ -0.025,  0.000,  0.000]
# Episode =  554, R_average =  -0.024, Position: [ -0.024,  0.000,  0.000]
# Episode =  555, R_average =  -0.024, Position: [ -0.026, -0.000,  0.000]
# Episode =  556, R_average =  -0.024, Position: [ -0.025,  0.000,  0.000]
# Episode =  557, R_average =  -0.024, Position: [ -0.026,  0.000,  0.000]
# Episode =  558, R_average =  -0.024, Position: [ -0.026,  0.000,  0.000]
# Episode =  559, R_average =  -0.024, Position: [ -0.025,  0.000,  0.000]
# Episode =  560, R_average =  -0.024, Position: [ -0.025,  0.000,  0.000]
# Episode =  561, R_average =  -0.024, Position: [ -0.025,  0.000,  0.000]
# Episode =  562, R_average =  -0.024, Position: [ -0.025,  0.000,  0.000]
# Episode =  563, R_average =  -0.024, Position: [ -0.025, -0.000,  0.000]
# Episode =  564, R_average =  -0.024, Position: [ -0.026,  0.000,  0.000]
# Episode =  565, R_average =  -0.024, Position: [ -0.025,  0.000,  0.000]
# Episode =  566, R_average =  -0.024, Position: [ -0.025, -0.000,  0.000]
# Episode =  567, R_average =  -0.024, Position: [ -0.024,  0.000,  0.000]
# Episode =  568, R_average =  -0.024, Position: [ -0.025,  0.000,  0.000]
# Episode =  569, R_average =  -0.023, Position: [ -0.025, -0.000,  0.000]
# Episode =  570, R_average =  -0.023, Position: [ -0.025, -0.000,  0.000]
# Episode =  571, R_average =  -0.023, Position: [ -0.025, -0.000,  0.000]
# Episode =  572, R_average =  -0.023, Position: [ -0.025, -0.000,  0.000]
# Episode =  573, R_average =  -0.023, Position: [ -0.025, -0.000,  0.000]
# Episode =  574, R_average =  -0.023, Position: [ -0.026, -0.000,  0.000]
# Episode =  575, R_average =  -0.023, Position: [ -0.026,  0.000,  0.000]
# Episode =  576, R_average =  -0.023, Position: [ -0.025, -0.000,  0.000]
# Episode =  577, R_average =  -0.023, Position: [ -0.025, -0.000,  0.000]
# Episode =  578, R_average =  -0.023, Position: [ -0.025, -0.000,  0.000]
# Episode =  579, R_average =  -0.023, Position: [ -0.025, -0.000,  0.000]
# Episode =  580, R_average =  -0.023, Position: [ -0.024, -0.000,  0.000]
# Episode =  581, R_average =  -0.023, Position: [ -0.026, -0.000,  0.000]
# Episode =  582, R_average =  -0.023, Position: [ -0.026, -0.000,  0.000]
# Episode =  583, R_average =  -0.023, Position: [ -0.025, -0.000,  0.000]
# Episode =  584, R_average =  -0.023, Position: [ -0.026, -0.000,  0.000]
# Episode =  585, R_average =  -0.023, Position: [ -0.025,  0.000,  0.000]
# Episode =  586, R_average =  -0.023, Position: [ -0.025, -0.000,  0.000]
# Episode =  587, R_average =  -0.023, Position: [ -0.026,  0.000,  0.000]
# Episode =  588, R_average =  -0.023, Position: [ -0.025, -0.000,  0.000]
# Episode =  589, R_average =  -0.023, Position: [ -0.025, -0.000,  0.000]
# Episode =  590, R_average =  -0.023, Position: [ -0.026, -0.000,  0.000]
# Episode =  591, R_average =  -0.023, Position: [ -0.025,  0.000,  0.000]
# Episode =  592, R_average =  -0.023, Position: [ -0.026, -0.000,  0.000]
# Episode =  593, R_average =  -0.023, Position: [ -0.026, -0.000,  0.000]
# Episode =  594, R_average =  -0.022, Position: [ -0.026, -0.000,  0.000]
# Episode =  595, R_average =  -0.022, Position: [ -0.026, -0.000,  0.000]
# Episode =  596, R_average =  -0.022, Position: [ -0.025,  0.000,  0.000]
# Episode =  597, R_average =  -0.022, Position: [ -0.025,  0.000,  0.000]
# Episode =  598, R_average =  -0.022, Position: [ -0.026,  0.000,  0.000]
# Episode =  599, R_average =  -0.022, Position: [ -0.025, -0.000,  0.000]
# Episode =  600, R_average =  -0.022, Position: [ -0.025,  0.000,  0.000]
# Episode =  601, R_average =  -0.022, Position: [ -0.026, -0.000,  0.000]
# Episode =  602, R_average =  -0.022, Position: [ -0.026,  0.000,  0.000]
# Episode =  603, R_average =  -0.022, Position: [ -0.025,  0.000,  0.000]
# Episode =  604, R_average =  -0.022, Position: [ -0.026,  0.000,  0.000]
# Episode =  605, R_average =  -0.022, Position: [ -0.025,  0.000,  0.000]
# Episode =  606, R_average =  -0.022, Position: [ -0.026,  0.000,  0.000]
# Episode =  607, R_average =  -0.022, Position: [ -0.024, -0.000,  0.000]
# Episode =  608, R_average =  -0.022, Position: [ -0.026,  0.000,  0.000]
# Episode =  609, R_average =  -0.022, Position: [ -0.025,  0.000,  0.000]
# Episode =  610, R_average =  -0.022, Position: [ -0.025, -0.000,  0.000]
# Episode =  611, R_average =  -0.022, Position: [ -0.025,  0.000,  0.000]
# Episode =  612, R_average =  -0.022, Position: [ -0.026, -0.000,  0.000]
# Episode =  613, R_average =  -0.022, Position: [ -0.026, -0.000,  0.000]
# Episode =  614, R_average =  -0.022, Position: [ -0.025,  0.000,  0.000]
# Episode =  615, R_average =  -0.022, Position: [ -0.025,  0.000,  0.000]
# Episode =  616, R_average =  -0.022, Position: [ -0.026,  0.000,  0.000]
# Episode =  617, R_average =  -0.022, Position: [ -0.026, -0.000,  0.000]
# Episode =  618, R_average =  -0.022, Position: [ -0.025,  0.000,  0.000]
# Episode =  619, R_average =  -0.022, Position: [ -0.025,  0.000,  0.000]
# Episode =  620, R_average =  -0.022, Position: [ -0.025,  0.000,  0.000]
# Episode =  621, R_average =  -0.021, Position: [ -0.025, -0.000,  0.000]
# Episode =  622, R_average =  -0.021, Position: [ -0.025, -0.000,  0.000]
# Episode =  623, R_average =  -0.021, Position: [ -0.026, -0.000,  0.000]
# Episode =  624, R_average =  -0.021, Position: [ -0.026,  0.000,  0.000]
# Episode =  625, R_average =  -0.021, Position: [ -0.025, -0.000,  0.000]
# Episode =  626, R_average =  -0.021, Position: [ -0.025,  0.000,  0.000]
# Episode =  627, R_average =  -0.021, Position: [ -0.024, -0.000,  0.000]
# Episode =  628, R_average =  -0.021, Position: [ -0.025,  0.000,  0.000]
# Episode =  629, R_average =  -0.021, Position: [ -0.025, -0.000,  0.000]
# Episode =  630, R_average =  -0.021, Position: [ -0.025,  0.000,  0.000]
# Episode =  631, R_average =  -0.021, Position: [ -0.025, -0.000,  0.000]
# Episode =  632, R_average =  -0.021, Position: [ -0.025,  0.000,  0.000]
# Episode =  633, R_average =  -0.021, Position: [ -0.026, -0.000,  0.000]
# Episode =  634, R_average =  -0.021, Position: [ -0.025,  0.000,  0.000]
# Episode =  635, R_average =  -0.021, Position: [ -0.025, -0.000,  0.000]
# Episode =  636, R_average =  -0.021, Position: [ -0.026, -0.000,  0.000]
# Episode =  637, R_average =  -0.021, Position: [ -0.025, -0.000,  0.000]
# Episode =  638, R_average =  -0.021, Position: [ -0.026, -0.000,  0.000]
# Episode =  639, R_average =  -0.021, Position: [ -0.025, -0.000,  0.000]
# Episode =  640, R_average =  -0.021, Position: [ -0.025,  0.000,  0.000]
# Episode =  641, R_average =  -0.021, Position: [ -0.025, -0.000,  0.000]
# Episode =  642, R_average =  -0.021, Position: [ -0.025, -0.000,  0.000]
# Episode =  643, R_average =  -0.021, Position: [ -0.026, -0.000,  0.000]
# Episode =  644, R_average =  -0.021, Position: [ -0.026, -0.000,  0.000]
# Episode =  645, R_average =  -0.021, Position: [ -0.025,  0.000,  0.000]
# Episode =  646, R_average =  -0.021, Position: [ -0.026,  0.000,  0.000]
# Episode =  647, R_average =  -0.021, Position: [ -0.025, -0.000,  0.000]
# Episode =  648, R_average =  -0.021, Position: [ -0.026, -0.000,  0.000]
# Episode =  649, R_average =  -0.021, Position: [ -0.026,  0.000,  0.000]
# Episode =  650, R_average =  -0.021, Position: [ -0.025, -0.000,  0.000]
# Episode =  651, R_average =  -0.020, Position: [ -0.025,  0.000,  0.000]
# Episode =  652, R_average =  -0.020, Position: [ -0.025,  0.000,  0.000]
# Episode =  653, R_average =  -0.020, Position: [ -0.025, -0.000,  0.000]
# Episode =  654, R_average =  -0.020, Position: [ -0.026, -0.000,  0.000]
# Episode =  655, R_average =  -0.020, Position: [ -0.026,  0.000,  0.000]
# Episode =  656, R_average =  -0.020, Position: [ -0.025, -0.000,  0.000]
# Episode =  657, R_average =  -0.020, Position: [ -0.026, -0.000,  0.000]
# ...
# Episode =  782, R_average =  -0.017, Position: [ -0.025,  0.000,  0.000]
# Episode =  783, R_average =  -0.017, Position: [ -0.025, -0.000,  0.000]
# Episode =  784, R_average =  -0.017, Position: [ -0.024, -0.000,  0.000]
# Episode =  785, R_average =  -0.017, Position: [ -0.027,  0.000,  0.000]
# Episode =  786, R_average =  -0.017, Position: [ -0.026,  0.000,  0.000]
# Episode =  787, R_average =  -0.017, Position: [ -0.026, -0.000,  0.000]
# Episode =  788, R_average =  -0.017, Position: [ -0.025,  0.000,  0.000]
# Episode =  789, R_average =  -0.017, Position: [ -0.025,  0.000,  0.000]
# Episode =  790, R_average =  -0.017, Position: [ -0.025,  0.000,  0.000]
# Episode =  791, R_average =  -0.017, Position: [ -0.026,  0.000,  0.000]
# Episode =  792, R_average =  -0.017, Position: [ -0.025, -0.000,  0.000]
# Episode =  793, R_average =  -0.017, Position: [ -0.026,  0.000,  0.000]
# Episode =  794, R_average =  -0.017, Position: [ -0.025,  0.000,  0.000]
# Episode =  795, R_average =  -0.017, Position: [ -0.026,  0.000,  0.000]
# Episode =  796, R_average =  -0.017, Position: [ -0.025, -0.000,  0.000]
# Episode =  797, R_average =  -0.017, Position: [ -0.025,  0.000,  0.000]
# Episode =  798, R_average =  -0.017, Position: [ -0.025,  0.000,  0.000]
# Episode =  799, R_average =  -0.017, Position: [ -0.025, -0.000,  0.000]
# Episode =  800, R_average =  -0.017, Position: [ -0.026, -0.000,  0.000]
# Episode =  801, R_average =  -0.017, Position: [ -0.026, -0.000,  0.000]
# Episode =  802, R_average =  -0.017, Position: [ -0.025, -0.000,  0.000]
# Episode =  803, R_average =  -0.017, Position: [ -0.025, -0.000,  0.000]
# Episode =  804, R_average =  -0.017, Position: [ -0.025,  0.000,  0.000]
# Episode =  805, R_average =  -0.017, Position: [ -0.025, -0.000,  0.000]
# Episode =  806, R_average =  -0.017, Position: [ -0.026,  0.000,  0.000]
# Episode =  807, R_average =  -0.017, Position: [ -0.025,  0.000,  0.000]
# Episode =  808, R_average =  -0.016, Position: [ -0.025,  0.000,  0.000]
# Episode =  809, R_average =  -0.016, Position: [ -0.025, -0.000,  0.000]
# Episode =  810, R_average =  -0.016, Position: [ -0.025, -0.000,  0.000]
# Episode =  811, R_average =  -0.016, Position: [ -0.025, -0.000,  0.000]
# Episode =  812, R_average =  -0.016, Position: [ -0.025, -0.000,  0.000]
# Episode =  813, R_average =  -0.016, Position: [ -0.025, -0.000,  0.000]
# Episode =  814, R_average =  -0.016, Position: [ -0.025,  0.000,  0.000]
# Episode =  815, R_average =  -0.016, Position: [ -0.025,  0.000,  0.000]
# Episode =  816, R_average =  -0.016, Position: [ -0.025,  0.000,  0.000]
# Episode =  817, R_average =  -0.016, Position: [ -0.025, -0.000,  0.000]
# Episode =  818, R_average =  -0.016, Position: [ -0.026, -0.000,  0.000]
# Episode =  819, R_average =  -0.016, Position: [ -0.025, -0.000,  0.000]
# Episode =  820, R_average =  -0.016, Position: [ -0.025,  0.000,  0.000]
# Episode =  821, R_average =  -0.016, Position: [ -0.025,  0.000,  0.000]
# Episode =  822, R_average =  -0.016, Position: [ -0.026, -0.000,  0.000]
# Episode =  823, R_average =  -0.016, Position: [ -0.025, -0.000,  0.000]
# Episode =  824, R_average =  -0.016, Position: [ -0.026, -0.000,  0.000]
# Episode =  825, R_average =  -0.016, Position: [ -0.025,  0.000,  0.000]
# Episode =  826, R_average =  -0.016, Position: [ -0.026,  0.000,  0.000]
# Episode =  827, R_average =  -0.016, Position: [ -0.026, -0.000,  0.000]
# Episode =  828, R_average =  -0.016, Position: [ -0.026, -0.000,  0.000]
# Episode =  829, R_average =  -0.016, Position: [ -0.026,  0.000,  0.000]
# Episode =  830, R_average =  -0.016, Position: [ -0.025, -0.000,  0.000]
# Episode =  831, R_average =  -0.016, Position: [ -0.025, -0.000,  0.000]
# Episode =  832, R_average =  -0.016, Position: [ -0.025,  0.000,  0.000]
# Episode =  833, R_average =  -0.016, Position: [ -0.026, -0.000,  0.000]
# Episode =  834, R_average =  -0.016, Position: [ -0.026,  0.000,  0.000]
# Episode =  835, R_average =  -0.016, Position: [ -0.026, -0.000,  0.000]
# Episode =  836, R_average =  -0.016, Position: [ -0.026, -0.000,  0.000]
# Episode =  837, R_average =  -0.016, Position: [ -0.025, -0.000,  0.000]
# Episode =  838, R_average =  -0.016, Position: [ -0.026, -0.000,  0.000]
# Episode =  839, R_average =  -0.016, Position: [ -0.025, -0.000,  0.000]
# Episode =  840, R_average =  -0.016, Position: [ -0.026, -0.000,  0.000]
# Episode =  841, R_average =  -0.016, Position: [ -0.025, -0.000,  0.000]
# Episode =  842, R_average =  -0.016, Position: [ -0.026, -0.000,  0.000]
# Episode =  843, R_average =  -0.016, Position: [ -0.024,  0.000,  0.000]
# Episode =  844, R_average =  -0.016, Position: [ -0.026, -0.000,  0.000]
# Episode =  845, R_average =  -0.016, Position: [ -0.025,  0.000,  0.000]
# Episode =  846, R_average =  -0.016, Position: [ -0.026,  0.000,  0.000]
# Episode =  847, R_average =  -0.016, Position: [ -0.026, -0.000,  0.000]
# Episode =  848, R_average =  -0.016, Position: [ -0.024,  0.000,  0.000]
# Episode =  849, R_average =  -0.016, Position: [ -0.026,  0.000,  0.000]
# Episode =  850, R_average =  -0.016, Position: [ -0.025,  0.000,  0.000]
# Episode =  851, R_average =  -0.016, Position: [ -0.026,  0.000,  0.000]
# Episode =  852, R_average =  -0.016, Position: [ -0.025, -0.000,  0.000]
# Episode =  853, R_average =  -0.016, Position: [ -0.025, -0.000,  0.000]
# Episode =  854, R_average =  -0.016, Position: [ -0.026, -0.000,  0.000]
# Episode =  855, R_average =  -0.016, Position: [ -0.026,  0.000,  0.000]
# Episode =  856, R_average =  -0.016, Position: [ -0.025, -0.000,  0.000]
# Episode =  857, R_average =  -0.016, Position: [ -0.026,  0.000,  0.000]
# Episode =  858, R_average =  -0.016, Position: [ -0.025, -0.000,  0.000]
# Episode =  859, R_average =  -0.016, Position: [ -0.027, -0.000,  0.000]
# Episode =  860, R_average =  -0.015, Position: [ -0.026, -0.000,  0.000]
# Episode =  861, R_average =  -0.015, Position: [ -0.025, -0.000,  0.000]
# Episode =  862, R_average =  -0.015, Position: [ -0.025,  0.000,  0.000]
# Episode =  863, R_average =  -0.015, Position: [ -0.026,  0.000,  0.000]
# Episode =  864, R_average =  -0.015, Position: [ -0.026,  0.000,  0.000]
# Episode =  865, R_average =  -0.015, Position: [ -0.026,  0.000,  0.000]
# Episode =  866, R_average =  -0.015, Position: [ -0.025,  0.000,  0.000]
# Episode =  867, R_average =  -0.015, Position: [ -0.026, -0.000,  0.000]
# Episode =  868, R_average =  -0.015, Position: [ -0.025, -0.000,  0.000]
# Episode =  869, R_average =  -0.015, Position: [ -0.025,  0.000,  0.000]
# Episode =  870, R_average =  -0.015, Position: [ -0.025, -0.000,  0.000]
# Episode =  871, R_average =  -0.015, Position: [ -0.026, -0.000,  0.000]
# Episode =  872, R_average =  -0.015, Position: [ -0.026, -0.000,  0.000]
# Episode =  873, R_average =  -0.015, Position: [ -0.025, -0.000,  0.000]
# Episode =  874, R_average =  -0.015, Position: [ -0.025, -0.000,  0.000]
# Episode =  875, R_average =  -0.015, Position: [ -0.025, -0.000,  0.000]
# Episode =  876, R_average =  -0.015, Position: [ -0.025,  0.000,  0.000]
# Episode =  877, R_average =  -0.015, Position: [ -0.025, -0.000,  0.000]
# Episode =  878, R_average =  -0.015, Position: [ -0.026,  0.000,  0.000]
# Episode =  879, R_average =  -0.015, Position: [ -0.025, -0.000,  0.000]
# Episode =  880, R_average =  -0.015, Position: [ -0.025, -0.000,  0.000]
# Episode =  881, R_average =  -0.015, Position: [ -0.026,  0.000,  0.000]
# Episode =  882, R_average =  -0.015, Position: [ -0.025, -0.000,  0.000]
# Episode =  883, R_average =  -0.015, Position: [ -0.026, -0.000,  0.000]
# Episode =  884, R_average =  -0.015, Position: [ -0.025,  0.000,  0.000]
# Episode =  885, R_average =  -0.015, Position: [ -0.025,  0.000,  0.000]
# Episode =  886, R_average =  -0.015, Position: [ -0.026,  0.000,  0.000]
# Episode =  887, R_average =  -0.015, Position: [ -0.026,  0.000,  0.000]
# Episode =  888, R_average =  -0.015, Position: [ -0.025,  0.000,  0.000]
# Episode =  889, R_average =  -0.015, Position: [ -0.026,  0.000,  0.000]
# Episode =  890, R_average =  -0.015, Position: [ -0.026,  0.000,  0.000]
# Episode =  891, R_average =  -0.015, Position: [ -0.025, -0.000,  0.000]
# Episode =  892, R_average =  -0.015, Position: [ -0.026, -0.000,  0.000]
# Episode =  893, R_average =  -0.015, Position: [ -0.026, -0.000,  0.000]
# Episode =  894, R_average =  -0.015, Position: [ -0.025, -0.000,  0.000]
# Episode =  895, R_average =  -0.015, Position: [ -0.025,  0.000,  0.000]
# Episode =  896, R_average =  -0.015, Position: [ -0.026,  0.000,  0.000]
# Episode =  897, R_average =  -0.015, Position: [ -0.025,  0.000,  0.000]
# Episode =  898, R_average =  -0.015, Position: [ -0.025,  0.000,  0.000]
# Episode =  899, R_average =  -0.015, Position: [ -0.025,  0.000,  0.000]
# Episode =  900, R_average =  -0.015, Position: [ -0.026, -0.000,  0.000]
# Episode =  901, R_average =  -0.015, Position: [ -0.025,  0.000,  0.000]
# Episode =  902, R_average =  -0.015, Position: [ -0.025,  0.000,  0.000]
# Episode =  903, R_average =  -0.015, Position: [ -0.026,  0.000,  0.000]
# Episode =  904, R_average =  -0.015, Position: [ -0.026,  0.000,  0.000]
# Episode =  905, R_average =  -0.015, Position: [ -0.025,  0.000,  0.000]
# Episode =  906, R_average =  -0.015, Position: [ -0.026, -0.000,  0.000]
# Episode =  907, R_average =  -0.015, Position: [ -0.024,  0.000,  0.000]
# Episode =  908, R_average =  -0.015, Position: [ -0.025,  0.000,  0.000]
# Episode =  909, R_average =  -0.015, Position: [ -0.025, -0.000,  0.000]
# Episode =  910, R_average =  -0.015, Position: [ -0.026,  0.000,  0.000]
# Episode =  911, R_average =  -0.015, Position: [ -0.024,  0.000,  0.000]
# Episode =  912, R_average =  -0.015, Position: [ -0.026, -0.000,  0.000]
# Episode =  913, R_average =  -0.015, Position: [ -0.026,  0.000,  0.000]
# Episode =  914, R_average =  -0.015, Position: [ -0.025, -0.000,  0.000]
# Episode =  915, R_average =  -0.015, Position: [ -0.026,  0.000,  0.000]
# Episode =  916, R_average =  -0.015, Position: [ -0.025, -0.000,  0.000]
# Episode =  917, R_average =  -0.015, Position: [ -0.025,  0.000,  0.000]
# Episode =  918, R_average =  -0.015, Position: [ -0.025, -0.000,  0.000]
# Episode =  919, R_average =  -0.014, Position: [ -0.025, -0.000,  0.000]
# Episode =  920, R_average =  -0.014, Position: [ -0.026, -0.000,  0.000]
# Episode =  921, R_average =  -0.014, Position: [ -0.025, -0.000,  0.000]
# Episode =  922, R_average =  -0.014, Position: [ -0.026, -0.000,  0.000]
# Episode =  923, R_average =  -0.014, Position: [ -0.026,  0.000,  0.000]
# Episode =  924, R_average =  -0.014, Position: [ -0.025, -0.000,  0.000]
# Episode =  925, R_average =  -0.014, Position: [ -0.026, -0.000,  0.000]
# Episode =  926, R_average =  -0.014, Position: [ -0.026,  0.000,  0.000]
# Episode =  927, R_average =  -0.014, Position: [ -0.025, -0.000,  0.000]
# Episode =  928, R_average =  -0.014, Position: [ -0.025,  0.000,  0.000]
# Episode =  929, R_average =  -0.014, Position: [ -0.026, -0.000,  0.000]
# Episode =  930, R_average =  -0.014, Position: [ -0.025,  0.000,  0.000]
# Episode =  931, R_average =  -0.014, Position: [ -0.025,  0.000,  0.000]
# Episode =  932, R_average =  -0.014, Position: [ -0.026, -0.000,  0.000]
# Episode =  933, R_average =  -0.014, Position: [ -0.025, -0.000,  0.000]
# Episode =  934, R_average =  -0.014, Position: [ -0.026,  0.000,  0.000]
# Episode =  935, R_average =  -0.014, Position: [ -0.025, -0.000,  0.000]
# Episode =  936, R_average =  -0.014, Position: [ -0.025,  0.000,  0.000]
# Episode =  937, R_average =  -0.014, Position: [ -0.026, -0.000,  0.000]
# Episode =  938, R_average =  -0.014, Position: [ -0.025,  0.000,  0.000]
# Episode =  939, R_average =  -0.014, Position: [ -0.026, -0.000,  0.000]
# Episode =  940, R_average =  -0.014, Position: [ -0.026,  0.000,  0.000]
# Episode =  941, R_average =  -0.014, Position: [ -0.026,  0.000,  0.000]
# Episode =  942, R_average =  -0.014, Position: [ -0.025, -0.000,  0.000]
# Episode =  943, R_average =  -0.014, Position: [ -0.025,  0.000,  0.000]
# Episode =  944, R_average =  -0.014, Position: [ -0.025,  0.000,  0.000]
# Episode =  945, R_average =  -0.014, Position: [ -0.025,  0.000,  0.000]
# Episode =  946, R_average =  -0.014, Position: [ -0.025, -0.000,  0.000]
# Episode =  947, R_average =  -0.014, Position: [ -0.025,  0.000,  0.000]
# Episode =  948, R_average =  -0.014, Position: [ -0.026,  0.000,  0.000]
# Episode =  949, R_average =  -0.014, Position: [ -0.026, -0.000,  0.000]
# Episode =  950, R_average =  -0.014, Position: [ -0.026, -0.000,  0.000]
# Episode =  951, R_average =  -0.014, Position: [ -0.026,  0.000,  0.000]
# Episode =  952, R_average =  -0.014, Position: [ -0.026,  0.000,  0.000]
# Episode =  953, R_average =  -0.014, Position: [ -0.026, -0.000,  0.000]
# Episode =  954, R_average =  -0.014, Position: [ -0.025,  0.000,  0.000]
# Episode =  955, R_average =  -0.014, Position: [ -0.024, -0.000,  0.000]
# Episode =  956, R_average =  -0.014, Position: [ -0.025,  0.000,  0.000]
# Episode =  957, R_average =  -0.014, Position: [ -0.025, -0.000,  0.000]
# Episode =  958, R_average =  -0.014, Position: [ -0.026, -0.000,  0.000]
# Episode =  959, R_average =  -0.014, Position: [ -0.025,  0.000,  0.000]
# Episode =  960, R_average =  -0.014, Position: [ -0.026,  0.000,  0.000]
# Episode =  961, R_average =  -0.014, Position: [ -0.025,  0.000,  0.000]
# Episode =  962, R_average =  -0.014, Position: [ -0.026,  0.000,  0.000]
# Episode =  963, R_average =  -0.014, Position: [ -0.025,  0.000,  0.000]
# Episode =  964, R_average =  -0.014, Position: [ -0.026,  0.000,  0.000]
# Episode =  965, R_average =  -0.014, Position: [ -0.025, -0.000,  0.000]
# Episode =  966, R_average =  -0.014, Position: [ -0.025,  0.000,  0.000]
# Episode =  967, R_average =  -0.014, Position: [ -0.026, -0.000,  0.000]
# Episode =  968, R_average =  -0.014, Position: [ -0.026, -0.000,  0.000]
# Episode =  969, R_average =  -0.014, Position: [ -0.025, -0.000,  0.000]
# Episode =  970, R_average =  -0.014, Position: [ -0.026,  0.000,  0.000]
# Episode =  971, R_average =  -0.014, Position: [ -0.025, -0.000,  0.000]
# Episode =  972, R_average =  -0.014, Position: [ -0.026, -0.000,  0.000]
# Episode =  973, R_average =  -0.014, Position: [ -0.025, -0.000,  0.000]
# Episode =  974, R_average =  -0.014, Position: [ -0.025,  0.000,  0.000]
# Episode =  975, R_average =  -0.014, Position: [ -0.025, -0.000,  0.000]
# Episode =  976, R_average =  -0.014, Position: [ -0.025,  0.000,  0.000]
# Episode =  977, R_average =  -0.014, Position: [ -0.026, -0.000,  0.000]
# Episode =  978, R_average =  -0.014, Position: [ -0.025, -0.000,  0.000]
# Episode =  979, R_average =  -0.014, Position: [ -0.025, -0.000,  0.000]
# Episode =  980, R_average =  -0.014, Position: [ -0.025,  0.000,  0.000]
# Episode =  981, R_average =  -0.014, Position: [ -0.025,  0.000,  0.000]
# Episode =  982, R_average =  -0.014, Position: [ -0.026, -0.000,  0.000]
# Episode =  983, R_average =  -0.014, Position: [ -0.025,  0.000,  0.000]
# Episode =  984, R_average =  -0.014, Position: [ -0.025,  0.000,  0.000]
# Episode =  985, R_average =  -0.014, Position: [ -0.025, -0.000,  0.000]
# Episode =  986, R_average =  -0.014, Position: [ -0.025, -0.000,  0.000]
# Episode =  987, R_average =  -0.013, Position: [ -0.025, -0.000,  0.000]
# Episode =  988, R_average =  -0.013, Position: [ -0.025, -0.000,  0.000]
# Episode =  989, R_average =  -0.013, Position: [ -0.026,  0.000,  0.000]
# Episode =  990, R_average =  -0.013, Position: [ -0.025, -0.000,  0.000]
# Episode =  991, R_average =  -0.013, Position: [ -0.026, -0.000,  0.000]
# Episode =  992, R_average =  -0.013, Position: [ -0.026, -0.000,  0.000]
# Episode =  993, R_average =  -0.013, Position: [ -0.026,  0.000,  0.000]
# Episode =  994, R_average =  -0.013, Position: [ -0.025, -0.000,  0.000]
# Episode =  995, R_average =  -0.013, Position: [ -0.026, -0.000,  0.000]
# Episode =  996, R_average =  -0.013, Position: [ -0.025, -0.000,  0.000]
# Episode =  997, R_average =  -0.013, Position: [ -0.026, -0.000,  0.000]
# Episode =  998, R_average =  -0.013, Position: [ -0.025,  0.000,  0.000]
# Episode =  999, R_average =  -0.013, Position: [ -0.026, -0.000,  0.000]
# Episode = 1000, R_average =  -0.013, Position: [ -0.025,  0.000,  0.000]

# %% [markdown]
# ## Plot the Rewards
#
# Once you are satisfied with your performance, plot the episode rewards, either from a single run, or averaged over multiple runs.

# %%
## TODO: Plot the rewards.

# %% [markdown]
# ## Reflections
#
# **Question 1**: Describe the task that you specified in `task.py`.  How did you design the reward function?
#
# **Answer**:

# %% [markdown]
# **Question 2**: Discuss your agent briefly, using the following questions as a guide:
#
# - What learning algorithm(s) did you try? What worked best for you?
# - What was your final choice of hyperparameters (such as $\alpha$, $\gamma$, $\epsilon$, etc.)?
# - What neural network architecture did you use (if any)? Specify layers, sizes, activation functions, etc.
#
# **Answer**:

# %% [markdown]
# **Question 3**: Using the episode rewards plot, discuss how the agent learned over time.
#
# - Was it an easy task to learn or hard?
# - Was there a gradual learning curve, or an aha moment?
# - How good was the final performance of the agent? (e.g. mean rewards over the last 10 episodes)
#
# **Answer**:

# %% [markdown]
# **Question 4**: Briefly summarize your experience working on this project. You can use the following prompts for ideas.
#
# - What was the hardest part of the project? (e.g. getting started, plotting, specifying the task, etc.)
# - Did you find anything interesting in how the quadcopter or your agent behaved?
#
# **Answer**:
